# %% [markdown]
# --- Script fornecido pelo Grupo 7 e adaptado para o nosso trabalho ---

# %% [markdown]
# # *Klebsiella pneumoniae*

# %% [markdown]
# ## Através do GenBank

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio import Entrez
from Bio import SeqIO

#genes = ["KPC-2", "CTX-M-14", "MdtC"]
#genes = ["KPHS_p200360", "KPHS_p100340", "KPHS_35880"]
genes = ["NC_016846.1", "NC_016838.1", "NC_016845.1"]

#Aceder ao NCBI
Entrez.email = 'pg45967@uminho.pt'
handle = Entrez.efetch(db = "nucleotide", id = "CP003200.1", rettype = "gb", retmode = "text")
seq_record = SeqIO.read(handle, "gb")

#Criar um ficheiro
SeqIO.write(seq_record, f"klebsiella_pneumoniae.gb", "gb")
handle.close()

#Aceder aos dados
info = SeqIO.read("klebsiella_pneumoniae.gb", "gb") 

f = open(f"klebsiella_pneumoniae.gb")
info = SeqIO.read(f, "gb")

#print(info)
print(f"Gene Id: {info.id}")
print(f"Description: {info.description}")

taxonomia = ''.join(f"{m} | " for m in info.annotations["taxonomy"])
print(f"Taxonomy: {taxonomia[:-2]}")

print()
for i, ref in enumerate(info.annotations["references"]): print(f"\t-------- REFERENCE {i + 1} --------\n\n{ref}")
# Out:
# Gene Id: CP003200.1
# Description: Klebsiella pneumoniae subsp. pneumoniae HS11286, complete genome
# Taxonomy: Bacteria | Proteobacteria | Gammaproteobacteria | Enterobacterales | Enterobacteriaceae | Klebsiella/Raoultella group | Klebsiella
#
# 	-------- REFERENCE 1 --------
#
# location: [0:5333942]
# authors: Liu,P., Li,P., Jiang,X., Bi,D., Xie,Y., Tai,C., Deng,Z., Rajakumar,K. and Ou,H.Y.
# title: Complete Genome Sequence of Klebsiella pneumoniae subsp. pneumoniae HS11286, a Multidrug-Resistant Strain Isolated from Human Sputum
# journal: J. Bacteriol. 194 (7), 1841-1842 (2012)
# medline id:
# pubmed id: 22408243
# comment:
#
# 	-------- REFERENCE 2 --------
#
# location: [0:5333942]
# authors: Ou,H.-Y., Jiang,X., Liu,P. and Li,P.
# title: Direct Submission
# journal: Submitted (14-DEC-2011) State Key Laboratory of Microbial Metabolism, Shanghai Jiaotong University, 1954 Huashan Road, Shanghai 200030, China
# medline id:
# pubmed id:
# comment:

# %%
#print(info.features)

data = []

for value in info.features:
    try:
        gene_name = value.qualifiers["gene"][0]
    except KeyError:
        continue
    if value.type == "CDS" and gene_name in genes:
        #print(value)
        print(f"Gene Name: {gene_name}")
        print("Type:", value.type)
        locus_tag = value.qualifiers["locus_tag"][0]
        print(f"Gene Locus: {locus_tag}")
        print(f"Location: {value.location}")
        protein_id = value.qualifiers["protein_id"][0]
        pt_product = value.qualifiers["product"][0]
        description = ''.join(f"Protein {protein_id} has the function: {pt_product}")
        protein = ''.join(value.qualifiers["translation"][0])
        print(f"{description}\n-------- Sequence --------\n{protein}")
        data.append([gene_name, locus_tag, value.type, value.location, protein_id, pt_product[:46], f"{protein[:20]}..."])
        print("\n\t--------------------//--------------------\n")
        
    """elif value.type == "rRNA" and gene_name in genes:
        #print(value)
        print(f"Gene Name: {gene_name}")
        print("Type:", value.type)
        print(f"Location: {value.location}")
        prot_obt = value.qualifiers["product"][0]
        print(f"Protein Obtained: {prot_obt}")
        data.append([gene_name, "----", value.type, value.location, "----", prot_obt[:46], "----"])
        print("\n\t--------------------//--------------------\n")"""

#for i in info.features:
    #print(i)

# %% [markdown]
# ## Matriz com as infos

# %%
import numpy as np
import pandas as pd
from tabulate import tabulate

info_firstline = ["Gene Name", "Gene Locus", "Type", "Location", "Protein ID", "Protein Function", "Protein Seq"]

numpy_data = np.array(data)
numpy_data_frame = numpy_data.reshape((3, 7))

info_genes = pd.DataFrame(data = numpy_data_frame, columns = info_firstline)
print(tabulate(info_genes, headers='keys', tablefmt='psql'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-5dbb13178cba> in <module>
#       6
#       7 numpy_data = np.array(data)
# ----> 8 numpy_data_frame = numpy_data.reshape((3, 7))
#       9
#      10 info_genes = pd.DataFrame(data = numpy_data_frame, columns = info_firstline)
#
# ValueError: cannot reshape array of size 0 into shape (3,7)

# %% [markdown]
# ## Obtenção do ficheiro xml com info do BLAST

# %% [markdown]
# ### Place in the input which gene you want to BLAST and retrieve the information

# %%
from Bio import SeqIO
from Bio.Blast import NCBIWWW 

while True:
    try:
        x = input("Which gene are you looking for (KPC-2, CTX-M-14 or MdtC):")
        if x not in ["KPC-2", "CTX-M-14", "MdtC"]: 
            raise ValueError("Inserted gene not valid!")
        break
    except ValueError as error:
        print(error)

f = open(f"{x}.fasta")
seq = SeqIO.read(f, "fasta")

result_handle = NCBIWWW.qblast("blastn", "nt", seq.format("fasta"))
save_file = open(f"{x}_BLAST.xml", "w")
save_file.write(result_handle.read())
save_file.close()
result_handle.close()
# Out:
# Which gene are you looking for (KPC-2, CTX-M-14 or MdtC): MdtC

# %% [markdown]
# ## Análise Ficheiro xml

# %%
from Bio.Blast import NCBIXML
import json

result_handle = open(f"{x}_BLAST.xml")
blast_records = NCBIXML.parse(result_handle)

allhits = []
hits = []
ids = []
for blast_record in blast_records:
    for alignment in blast_record.alignments: 
        for hsp in alignment.hsps:
            dict_all = {}
            info_hit = []
            if alignment.hit_id.split("|")[3] not in ids:
                info_hit.extend((alignment.hit_def, alignment.hit_id.split("|")[3], alignment.length, hsp.expect, hsp.score, alignment.accession))
                dict_all["Info"] = alignment.hit_def
                dict_all["Hit"] = alignment.hit_id.split("|")[3]
                ids.append(alignment.hit_id.split("|")[3])
                dict_all["Lenght"] = alignment.length
                dict_all["E-value"] = hsp.expect
                dict_all["Score"] = hsp.score
                dict_all["Accession Number"] = alignment.accession
                allhits.append(dict_all)
                hits.append(info_hit)
            
print(f"Number of hits: {len(allhits)}")
print(json.dumps(allhits, indent = 3))
# Out:
# Number of hits: 50
# [
#    {
#       "Info": "Klebsiella pneumoniae strain F17KP0054 chromosome, complete genome",
#       "Hit": "CP052136.1",
#       "Lenght": 5357257,
#       "E-value": 0.0,
#       "Score": 6156.0,
#       "Accession Number": "CP052136"
#    },
#    {
#       "Info": "Klebsiella pneumoniae isolate 97ca48c2-b809-11e8-aae5-3c4a9275d6c8 genome assembly, chromosome: 1 >gi|1772506384|emb|LR736022.1| Klebsiella pneumoniae strain Kp_17035 genome assembly, chromosome: 1",
#       "Hit": "LR596810.1",
#       "Lenght": 5577545,
#       "E-value": 0.0,
#       "Score": 6156.0,
#       "Accession Number": "LR596810"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain JS187 chromosome, complete genome",
#       "Hit": "CP025466.1",
#       "Lenght": 5359967,
#       "E-value": 0.0,
#       "Score": 6156.0,
#       "Accession Number": "CP025466"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain JS706 chromosome, complete genome",
#       "Hit": "CP070970.1",
#       "Lenght": 5339678,
#       "E-value": 0.0,
#       "Score": 6156.0,
#       "Accession Number": "CP070970"
#    },
#    {
#       "Info": "Klebsiella pneumoniae subsp. pneumoniae HS11286, complete genome",
#       "Hit": "CP003200.1",
#       "Lenght": 5333942,
#       "E-value": 0.0,
#       "Score": 6156.0,
#       "Accession Number": "CP003200"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 1613015451 chromosome, complete genome",
#       "Hit": "CP083066.1",
#       "Lenght": 5340602,
#       "E-value": 0.0,
#       "Score": 6111.0,
#       "Accession Number": "CP083066"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KSB1_1B genome assembly, chromosome: 1",
#       "Hit": "LR890291.1",
#       "Lenght": 5252324,
#       "E-value": 0.0,
#       "Score": 6111.0,
#       "Accession Number": "LR890291"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain FDAARGOS_1313 chromosome, complete genome",
#       "Hit": "CP069907.1",
#       "Lenght": 5220139,
#       "E-value": 0.0,
#       "Score": 6081.0,
#       "Accession Number": "CP069907"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain RHBSTW-00433 chromosome, complete genome",
#       "Hit": "CP056530.1",
#       "Lenght": 5240044,
#       "E-value": 0.0,
#       "Score": 6081.0,
#       "Accession Number": "CP056530"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain RHBSTW-00510 chromosome, complete genome",
#       "Hit": "CP056432.1",
#       "Lenght": 5342507,
#       "E-value": 0.0,
#       "Score": 6081.0,
#       "Accession Number": "CP056432"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KPN1344 chromosome",
#       "Hit": "CP033901.1",
#       "Lenght": 5343965,
#       "E-value": 0.0,
#       "Score": 6076.0,
#       "Accession Number": "CP033901"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain HZW25 chromosome, complete genome",
#       "Hit": "CP025211.1",
#       "Lenght": 5198587,
#       "E-value": 0.0,
#       "Score": 6076.0,
#       "Accession Number": "CP025211"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain INF116-sc-2279924 chromosome, complete genome",
#       "Hit": "CP031792.1",
#       "Lenght": 5270163,
#       "E-value": 0.0,
#       "Score": 6071.0,
#       "Accession Number": "CP031792"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain Colony255 chromosome",
#       "Hit": "CP078765.1",
#       "Lenght": 5540574,
#       "E-value": 0.0,
#       "Score": 6071.0,
#       "Accession Number": "CP078765"
#    },
#    {
#       "Info": "Klebsiella pneumoniae KSB1_9A DNA, complete genome",
#       "Hit": "AP024173.1",
#       "Lenght": 5242098,
#       "E-value": 0.0,
#       "Score": 6071.0,
#       "Accession Number": "AP024173"
#    },
#    {
#       "Info": "Klebsiella pneumoniae isolate INF008-sc-2279879 genome assembly, chromosome: 1",
#       "Hit": "LR890202.1",
#       "Lenght": 5325686,
#       "E-value": 0.0,
#       "Score": 6071.0,
#       "Accession Number": "LR890202"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain RHB16-C24 chromosome, complete genome",
#       "Hit": "CP057722.1",
#       "Lenght": 5134919,
#       "E-value": 0.0,
#       "Score": 6071.0,
#       "Accession Number": "CP057722"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain C17KP0055 chromosome, complete genome",
#       "Hit": "CP052386.1",
#       "Lenght": 5083236,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP052386"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain LH375 chromosome, complete genome",
#       "Hit": "CP035196.1",
#       "Lenght": 5175568,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP035196"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KP14003 chromosome, complete genome",
#       "Hit": "CP041934.1",
#       "Lenght": 5293274,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP041934"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain F93-1 chromosome, complete genome",
#       "Hit": "CP026160.1",
#       "Lenght": 5191009,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP026160"
#    },
#    {
#       "Info": "Klebsiella pneumoniae subsp. pneumoniae strain KPNIH29, complete genome",
#       "Hit": "CP009863.1",
#       "Lenght": 5298647,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP009863"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain Colony445 chromosome",
#       "Hit": "CP078774.1",
#       "Lenght": 5540574,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP078774"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 2016-1400 chromosome, complete genome",
#       "Hit": "CP065034.1",
#       "Lenght": 5088943,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP065034"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain BS317-1 chromosome, complete genome",
#       "Hit": "CP063936.1",
#       "Lenght": 5058265,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "CP063936"
#    },
#    {
#       "Info": "Klebsiella pneumoniae isolate INF323-sc-2280125 genome assembly, chromosome: 1",
#       "Hit": "LR890735.1",
#       "Lenght": 5220279,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "LR890735"
#    },
#    {
#       "Info": "Klebsiella pneumoniae isolate INF358-sc-2280191 genome assembly, chromosome: 1",
#       "Hit": "LR890474.1",
#       "Lenght": 5300439,
#       "E-value": 0.0,
#       "Score": 6066.0,
#       "Accession Number": "LR890474"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain F4 chromosome, complete genome",
#       "Hit": "CP090397.1",
#       "Lenght": 5249104,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP090397"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KPN342 chromosome, complete genome",
#       "Hit": "CP089383.1",
#       "Lenght": 5172055,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP089383"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 53374 chromosome, complete genome",
#       "Hit": "CP089014.1",
#       "Lenght": 5383183,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP089014"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 56661 chromosome, complete genome",
#       "Hit": "CP089001.1",
#       "Lenght": 5370996,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP089001"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 53322 chromosome, complete genome",
#       "Hit": "CP088988.1",
#       "Lenght": 5373674,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP088988"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 7008.20 chromosome, complete genome",
#       "Hit": "CP082988.1",
#       "Lenght": 5368754,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP082988"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KP-PA chromosome, complete genome",
#       "Hit": "CP084984.1",
#       "Lenght": 5379443,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP084984"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain DJ genome assembly, chromosome: DJ_",
#       "Hit": "OV049808.1",
#       "Lenght": 5472771,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "OV049808"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain SCPM-O-B-8923 (3TKP/19g) chromosome, complete genome",
#       "Hit": "CP086671.1",
#       "Lenght": 5351820,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP086671"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain SCPM-O-B-8912 (11PKP/19a) chromosome, complete genome",
#       "Hit": "CP086664.1",
#       "Lenght": 5351360,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP086664"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain Kp1 chromosome, complete genome",
#       "Hit": "CP086285.1",
#       "Lenght": 5226596,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP086285"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain SB1139 chromosome, complete genome",
#       "Hit": "CP084859.1",
#       "Lenght": 5385248,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP084859"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain C2051 chromosome",
#       "Hit": "CP073920.1",
#       "Lenght": 5280286,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP073920"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain C1672 chromosome",
#       "Hit": "CP073917.1",
#       "Lenght": 5345842,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP073917"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain C11 chromosome, complete genome",
#       "Hit": "CP084103.1",
#       "Lenght": 5171985,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP084103"
#    },
#    {
#       "Info": "Klebsiella pneumoniae subsp. pneumoniae strain MRSN752019 chromosome, complete genome",
#       "Hit": "CP084397.1",
#       "Lenght": 5414231,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP084397"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain ER17974.3 chromosome, complete genome",
#       "Hit": "CP059295.1",
#       "Lenght": 5371012,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP059295"
#    },
#    {
#       "Info": "Klebsiella pneumoniae genome assembly, chromosome: 1",
#       "Hit": "OU453210.1",
#       "Lenght": 5497511,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "OU453210"
#    },
#    {
#       "Info": "Klebsiella pneumoniae subsp. pneumoniae strain WRC29_CMC309MPCH chromosome, complete genome",
#       "Hit": "CP079673.1",
#       "Lenght": 5153904,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP079673"
#    },
#    {
#       "Info": "Klebsiella pneumoniae subsp. pneumoniae strain WRC10_CMC309MC chromosome, complete genome",
#       "Hit": "CP079599.1",
#       "Lenght": 5234529,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP079599"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain XH210 chromosome, complete genome",
#       "Hit": "CP052761.1",
#       "Lenght": 5120204,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP052761"
#    },
#    {
#       "Info": "Klebsiella pneumoniae subsp. pneumoniae strain WRC09_CMC309PC chromosome, complete genome",
#       "Hit": "CP079164.1",
#       "Lenght": 5299071,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP079164"
#    },
#    {
#       "Info": "Klebsiella pneumoniae subsp. pneumoniae strain WGR351 chromosome, complete genome",
#       "Hit": "CP076008.1",
#       "Lenght": 5418057,
#       "E-value": 0.0,
#       "Score": 6061.0,
#       "Accession Number": "CP076008"
#    }
# ]

# %%
import numpy as np
import pandas as pd
from tabulate import tabulate

info_firstline = ["Organism", "Identifier", "Lenght", "E-Value", "Score", "Accession Number"]

numpy_data = np.array(hits)
numpy_data_frame = numpy_data.reshape((len(numpy_data), 6))

info_genes = pd.DataFrame(data = numpy_data_frame, columns = info_firstline)
print(tabulate(info_genes, headers='keys', tablefmt='psql'))
# Out:
# +----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------+
# |    | Organism                                                                                                                                                                                              | Identifier   |   Lenght |   E-Value |   Score | Accession Number   |
# |----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------|
# |  0 | Klebsiella pneumoniae strain F17KP0054 chromosome, complete genome                                                                                                                                    | CP052136.1   |  5357257 |         0 |    6156 | CP052136           |
# |  1 | Klebsiella pneumoniae isolate 97ca48c2-b809-11e8-aae5-3c4a9275d6c8 genome assembly, chromosome: 1 >gi|1772506384|emb|LR736022.1| Klebsiella pneumoniae strain Kp_17035 genome assembly, chromosome: 1 | LR596810.1   |  5577545 |         0 |    6156 | LR596810           |
# |  2 | Klebsiella pneumoniae strain JS187 chromosome, complete genome                                                                                                                                        | CP025466.1   |  5359967 |         0 |    6156 | CP025466           |
# |  3 | Klebsiella pneumoniae strain JS706 chromosome, complete genome                                                                                                                                        | CP070970.1   |  5339678 |         0 |    6156 | CP070970           |
# |  4 | Klebsiella pneumoniae subsp. pneumoniae HS11286, complete genome                                                                                                                                      | CP003200.1   |  5333942 |         0 |    6156 | CP003200           |
# |  5 | Klebsiella pneumoniae strain 1613015451 chromosome, complete genome                                                                                                                                   | CP083066.1   |  5340602 |         0 |    6111 | CP083066           |
# |  6 | Klebsiella pneumoniae strain KSB1_1B genome assembly, chromosome: 1                                                                                                                                   | LR890291.1   |  5252324 |         0 |    6111 | LR890291           |
# |  7 | Klebsiella pneumoniae strain FDAARGOS_1313 chromosome, complete genome                                                                                                                                | CP069907.1   |  5220139 |         0 |    6081 | CP069907           |
# |  8 | Klebsiella pneumoniae strain RHBSTW-00433 chromosome, complete genome                                                                                                                                 | CP056530.1   |  5240044 |         0 |    6081 | CP056530           |
