# %% [markdown]
# --- Script fornecido pelo Grupo 7 e adaptado para o nosso trabalho ---

# %% [markdown]
# # *Klebsiella pneumoniae*
# ## BLAST individuais

# %% [markdown]
# # KPC-2

# %%
from Bio import SeqIO
from Bio.Blast import NCBIWWW 

x = "KPC-2"
f = open(f"{x}.fasta")
seq = SeqIO.read(f, "fasta")

result_handle = NCBIWWW.qblast("blastn", "nt", seq.format("fasta"))
save_file = open(f"{x}_BLAST.xml", "w")
save_file.write(result_handle.read())
save_file.close()
result_handle.close()

# %% [markdown]
# ## Análise Ficheiro xml

# %%
from Bio.Blast import NCBIXML
import json

result_handle = open(f"{x}_BLAST.xml")
blast_records = NCBIXML.parse(result_handle)

allhits = []
hits = []
ids = []
for blast_record in blast_records:
    for alignment in blast_record.alignments: 
        for hsp in alignment.hsps:
            dict_all = {}
            info_hit = []
            if alignment.hit_id.split("|")[3] not in ids:
                info_hit.extend((alignment.hit_def, alignment.hit_id.split("|")[3], alignment.length, hsp.expect, hsp.score, alignment.accession))
                dict_all["Info"] = alignment.hit_def
                dict_all["Hit"] = alignment.hit_id.split("|")[3]
                ids.append(alignment.hit_id.split("|")[3])
                dict_all["Length"] = alignment.length
                dict_all["E-value"] = hsp.expect
                dict_all["Score"] = hsp.score
                dict_all["Accession Number"] = alignment.accession
                allhits.append(dict_all)
                hits.append(info_hit)
            
print(f"Number of hits: {len(allhits)}")

print(json.dumps(allhits, indent = 3))
# Out:
# Number of hits: 50
# [
#    {
#       "Info": "Pseudomonas aeruginosa strain HdC plasmid unnamed, complete sequence",
#       "Hit": "OL780449.1",
#       "Length": 42750,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "OL780449"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain WCHKP115011 plasmid pKPC2_115011, complete sequence",
#       "Hit": "CP089954.1",
#       "Length": 157388,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP089954"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 37 plasmid pZZDX37-KPC, complete sequence",
#       "Hit": "MT810376.1",
#       "Length": 91216,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810376"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 2014052905 plasmid p52905-KPC, complete sequence",
#       "Hit": "MT810375.1",
#       "Length": 177735,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810375"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 2013112401-22171 plasmid p122171-KPC, complete sequence",
#       "Hit": "MT810374.1",
#       "Length": 112539,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810374"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 40 plasmid pTZ40-KPC, complete sequence",
#       "Hit": "MT810372.1",
#       "Length": 124760,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810372"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 81 plasmid pTZSL81-KPC, complete sequence",
#       "Hit": "MT810371.1",
#       "Length": 85182,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810371"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A2282 plasmid pA2282-KPC, complete sequence",
#       "Hit": "MT810370.1",
#       "Length": 94490,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810370"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 2014042281 plasmid p42281-KPC, complete sequence",
#       "Hit": "MT810369.1",
#       "Length": 115305,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810369"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A1702 plasmid pA1702-KPC, complete sequence",
#       "Hit": "MT810368.1",
#       "Length": 133110,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810368"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 68 plasmid pZZDX68-KPC, complete sequence",
#       "Hit": "MT810367.1",
#       "Length": 100329,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810367"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 484115-123 plasmid p115123-KPC, complete sequence",
#       "Hit": "MT810366.1",
#       "Length": 131621,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810366"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 16 plasmid pBJYY16-KPC, complete sequence",
#       "Hit": "MT810365.1",
#       "Length": 112814,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810365"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 67 plasmid pZZDX67-KPC, complete sequence",
#       "Hit": "MT810364.1",
#       "Length": 105915,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810364"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 170202604-1 plasmid p26041-KPC, complete sequence",
#       "Hit": "MT810363.1",
#       "Length": 100883,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810363"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 106 plasmid pBJY106-KPC, complete sequence",
#       "Hit": "MT810362.1",
#       "Length": 98973,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810362"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A2312 plasmid pA2312-KPC, complete sequence",
#       "Hit": "MT810361.1",
#       "Length": 88158,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810361"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A1825 plasmid pA1825-KPC, complete sequence",
#       "Hit": "MT810360.1",
#       "Length": 261717,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810360"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 20150420184 plasmid p420184-KPC, complete sequence",
#       "Hit": "MT810359.1",
#       "Length": 108236,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810359"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 2014010701-5001 plasmid p15001-KPC, complete sequence",
#       "Hit": "MT810358.1",
#       "Length": 129274,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810358"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A1697 plasmid pA1697-KPC, complete sequence",
#       "Hit": "MT810357.1",
#       "Length": 128588,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810357"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 246421 plasmid p246421-KPC, complete sequence",
#       "Hit": "MT810356.1",
#       "Length": 145209,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810356"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A1919 plasmid pA1919-KPC, complete sequence",
#       "Hit": "MT810355.1",
#       "Length": 104465,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810355"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A1708 plasmid pA1708-KPC, complete sequence",
#       "Hit": "MT810354.1",
#       "Length": 173280,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810354"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A1836 plasmid pA1836-KPC, complete sequence",
#       "Hit": "MT810353.1",
#       "Length": 150865,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810353"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain A1728 plasmid pA1728-KPC, complete sequence",
#       "Hit": "MT810352.1",
#       "Length": 76854,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MT810352"
#    },
#    {
#       "Info": "Klebsiella michiganensis strain 8-1 plasmid unnamed1, complete sequence",
#       "Hit": "CP089449.1",
#       "Length": 81451,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP089449"
#    },
#    {
#       "Info": "Escherichia coli strain 5-1 plasmid unnamed2, complete sequence",
#       "Hit": "CP089447.1",
#       "Length": 125150,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP089447"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 50700 plasmid p50700-140.6, complete sequence",
#       "Hit": "CP088995.1",
#       "Length": 140550,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP088995"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 49088 plasmid p49088-279.2, complete sequence",
#       "Hit": "CP089000.1",
#       "Length": 279210,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP089000"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 6711.43 plasmid p1-6711.43-KPC2, complete sequence",
#       "Hit": "CP083008.1",
#       "Length": 211349,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP083008"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain YZH2487 plasmid pYUYZH2487-1, complete sequence",
#       "Hit": "CP087707.1",
#       "Length": 217602,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP087707"
#    },
#    {
#       "Info": "Klebsiella quasipneumoniae strain OSUCMP263AKPC plasmid pCMP234-2, complete sequence",
#       "Hit": "CP087582.1",
#       "Length": 104872,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP087582"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain SCPM-O-B-8923 (3TKP/19g) plasmid pB-8923_KPC-2, complete sequence",
#       "Hit": "CP086675.1",
#       "Length": 102252,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP086675"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain SCPM-O-B-8912 (11PKP/19a) plasmid pKPC-2, complete sequence",
#       "Hit": "CP086668.1",
#       "Length": 102252,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP086668"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 59062CZ plasmid p59062CZ_IncC_KPC, complete sequence",
#       "Hit": "CP085731.1",
#       "Length": 170174,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP085731"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KP18-2110-2 plasmid pKP18-2110-2-2, complete sequence",
#       "Hit": "CP084988.1",
#       "Length": 142244,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP084988"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KP200731214 plasmid pKP-KPC-2",
#       "Hit": "CP084745.1",
#       "Length": 128928,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP084745"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain KP1064WHY plasmid p2, complete sequence",
#       "Hit": "CP084707.1",
#       "Length": 131273,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP084707"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain NTUH-K2044-CR plasmid unnamed2, complete sequence",
#       "Hit": "MZ475710.1",
#       "Length": 112901,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MZ475710"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain JS187-vir plasmid unnamed3, complete sequence",
#       "Hit": "MZ475702.1",
#       "Length": 110080,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MZ475702"
#    },
#    {
#       "Info": "Escherichia coli strain J53-vir plasmid unnamed2, partial sequence",
#       "Hit": "MZ475698.1",
#       "Length": 114278,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MZ475698"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain HS11286-vir2 plasmid unnamed2, complete sequence",
#       "Hit": "MZ475694.1",
#       "Length": 99645,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "MZ475694"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 1864 plasmid p1864-2, complete sequence",
#       "Hit": "CP084494.1",
#       "Length": 152725,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP084494"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 1632 plasmid p1632-1, complete sequence",
#       "Hit": "CP084498.1",
#       "Length": 163933,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP084498"
#    },
#    {
#       "Info": "Escherichia coli strain 035053C1pKPC2_Vir_090515B1 plasmid pKPC2_Vir_090515B1, complete sequence",
#       "Hit": "CP084027.1",
#       "Length": 351436,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP084027"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 36 plasmid pKP36-KPC, complete sequence",
#       "Hit": "CP082761.1",
#       "Length": 133771,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP082761"
#    },
#    {
#       "Info": "Klebsiella pneumoniae strain 12 plasmid pKP12-KPC, complete sequence",
#       "Hit": "CP082767.1",
#       "Length": 133376,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP082767"
#    },
#    {
#       "Info": "Pseudomonas aeruginosa strain FAHZU31 plasmid pFAHZU31-KPC, complete sequence",
#       "Hit": "CP078010.1",
#       "Length": 24350,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP078010"
#    },
#    {
#       "Info": "Pseudomonas aeruginosa strain FAHZU40 plasmid pFAHZU40-KPC, complete sequence",
#       "Hit": "CP078008.1",
#       "Length": 28700,
#       "E-value": 0.0,
#       "Score": 1764.0,
#       "Accession Number": "CP078008"
#    }
# ]

# %% [markdown]
# ## Obtenção do Dataframe para melhor análise do BLAST de KPC-2

# %%
import numpy as np
import pandas as pd
from tabulate import tabulate

info_firstline = ["Organism", "Identifier", "Length", "E-Value", "Score", "Accession Number"]

numpy_data = np.array(hits)
numpy_data_frame = numpy_data.reshape((len(numpy_data), 6))

info_genes = pd.DataFrame(data = numpy_data_frame, columns = info_firstline)
print(tabulate(info_genes, headers='keys', tablefmt='psql'))
# Out:
# +----+--------------------------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------+
# |    | Organism                                                                                         | Identifier   |   Lenght |   E-Value |   Score | Accession Number   |
# |----+--------------------------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------|
# |  0 | Pseudomonas aeruginosa strain HdC plasmid unnamed, complete sequence                             | OL780449.1   |    42750 |         0 |    1764 | OL780449           |
# |  1 | Klebsiella pneumoniae strain WCHKP115011 plasmid pKPC2_115011, complete sequence                 | CP089954.1   |   157388 |         0 |    1764 | CP089954           |
# |  2 | Klebsiella pneumoniae strain 37 plasmid pZZDX37-KPC, complete sequence                           | MT810376.1   |    91216 |         0 |    1764 | MT810376           |
# |  3 | Klebsiella pneumoniae strain 2014052905 plasmid p52905-KPC, complete sequence                    | MT810375.1   |   177735 |         0 |    1764 | MT810375           |
# |  4 | Klebsiella pneumoniae strain 2013112401-22171 plasmid p122171-KPC, complete sequence             | MT810374.1   |   112539 |         0 |    1764 | MT810374           |
# |  5 | Klebsiella pneumoniae strain 40 plasmid pTZ40-KPC, complete sequence                             | MT810372.1   |   124760 |         0 |    1764 | MT810372           |
# |  6 | Klebsiella pneumoniae strain 81 plasmid pTZSL81-KPC, complete sequence                           | MT810371.1   |    85182 |         0 |    1764 | MT810371           |
------------------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------+

# %% [markdown]
# # CTX-M-14

# %%
from Bio import SeqIO
from Bio.Blast import NCBIWWW 

x = "CTX-M-14"
f = open(f"{x}.fasta")
seq = SeqIO.read(f, "fasta")

result_handle = NCBIWWW.qblast("blastn", "nt", seq.format("fasta"))
save_file = open(f"{x}_BLAST.xml", "w")
save_file.write(result_handle.read())
save_file.close()
result_handle.close()

# %% [markdown]
# ## Análise Ficheiro xml

# %%
from Bio.Blast import NCBIXML
import json

result_handle = open(f"{x}_BLAST.xml")
blast_records = NCBIXML.parse(result_handle)

allhits = []
hits = []
ids = []
for blast_record in blast_records:
    for alignment in blast_record.alignments: 
        for hsp in alignment.hsps:
            dict_all = {}
            info_hit = []
            if alignment.hit_id.split("|")[3] not in ids:
                info_hit.extend((alignment.hit_def, alignment.hit_id.split("|")[3], alignment.length, hsp.expect, hsp.score, alignment.accession))
                dict_all["Info"] = alignment.hit_def
                dict_all["Hit"] = alignment.hit_id.split("|")[3]
                ids.append(alignment.hit_id.split("|")[3])
                dict_all["Length"] = alignment.length
                dict_all["E-value"] = hsp.expect
                dict_all["Score"] = hsp.score
                dict_all["Accession Number"] = alignment.accession
                allhits.append(dict_all)
                hits.append(info_hit)
            
#print(f"Number of hits: {len(allhits)}")
#print(json.dumps(allhits, indent = 3))

# %% [markdown]
# ## Obtenção do Dataframe para melhor análise do BLAST de CTX-M-14

# %%
import numpy as np
import pandas as pd
from tabulate import tabulate

info_firstline = ["Organism", "Identifier", "Length", "E-Value", "Score", "Accession Number"]

numpy_data = np.array(hits)
numpy_data_frame = numpy_data.reshape((len(numpy_data), 6))

info_genes = pd.DataFrame(data = numpy_data_frame, columns = info_firstline)
print(tabulate(info_genes, headers='keys', tablefmt='psql'))
# Out:
# +----+-------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------+
# |    | Organism                                                                      | Identifier   |   Lenght |   E-Value |   Score | Accession Number   |
# |----+-------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------|
# |  0 | Klebsiella pneumoniae strain 2014052905 plasmid p52905-KPC, complete sequence | MT810375.1   |   177735 |         0 |    1704 | MT810375           |
# |  1 | Klebsiella pneumoniae strain A1825 plasmid pA1825-KPC, complete sequence      | MT810360.1   |   261717 |         0 |    1704 | MT810360           |
# |  2 | Proteus mirabilis strain PM1162 chromosome, complete genome                   | CP089317.1   |  4202509 |         0 |    1704 | CP089317           |
# |  3 | Klebsiella pneumoniae KpWEA4-2 plasmid P2 DNA, complete sequence              | AP024581.1   |    36504 |         0 |    1704 | AP024581           |
# |  4 | Klebsiella pneumoniae KpWEA4-2 plasmid P1 DNA, complete sequence              | AP024580.1   |   220075 |         0 |    1704 | AP024580           |
# |  5 | Klebsiella pneumoniae KpWEA4-2 DNA, complete genome                           | AP024579.1   |  5389848 |         0 |    1704 | AP024579           |
# |  6 | Klebsiella pneumoniae KpWEA4-1 plasmid P2 DNA, complete sequence              | AP024578.1   |    36504 |         0 |    1704 | AP024578           |
------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------+

# %% [markdown]
# # MdtC

# %%
from Bio import SeqIO
from Bio.Blast import NCBIWWW 

x = "MdtC"
f = open(f"{x}.fasta")
seq = SeqIO.read(f, "fasta")

result_handle = NCBIWWW.qblast("blastn", "nt", seq.format("fasta"))
save_file = open(f"{x}_BLAST.xml", "w")
save_file.write(result_handle.read())
save_file.close()
result_handle.close()

# %% [markdown]
# ## Análise Ficheiro xml

# %%
from Bio.Blast import NCBIXML
import json
x = "MdtC"
result_handle = open(f"{x}_BLAST.xml")
blast_records = NCBIXML.parse(result_handle)

allhits = []
hits = []
ids = []
for blast_record in blast_records:
    for alignment in blast_record.alignments: 
        for hsp in alignment.hsps:
            dict_all = {}
            info_hit = []
            if alignment.hit_id.split("|")[3] not in ids:
                info_hit.extend((alignment.hit_def, alignment.hit_id.split("|")[3], alignment.length, hsp.expect, hsp.score, alignment.accession))
                dict_all["Info"] = alignment.hit_def
                dict_all["Hit"] = alignment.hit_id.split("|")[3]
                ids.append(alignment.hit_id.split("|")[3])
                dict_all["Length"] = alignment.length
                dict_all["E-value"] = hsp.expect
                dict_all["Score"] = hsp.score
                dict_all["Accession Number"] = alignment.accession
                allhits.append(dict_all)
                hits.append(info_hit)
            
#print(f"Number of hits: {len(allhits)}")
#print(json.dumps(allhits, indent = 3))

# %% [markdown]
# ## Obtenção do Dataframe para melhor análise do BLAST de MdtC

# %%
import numpy as np
import pandas as pd
from tabulate import tabulate

info_firstline = ["Organism", "Identifier", "Length", "E-Value", "Score", "Accession Number"]

numpy_data = np.array(hits)
numpy_data_frame = numpy_data.reshape((len(numpy_data), 6))

info_genes = pd.DataFrame(data = numpy_data_frame, columns = info_firstline)
print(tabulate(info_genes, headers='keys', tablefmt='psql'))
# Out:
# +----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------+
# |    | Organism                                                                                                                                                                                              | Identifier   |   Length |   E-Value |   Score | Accession Number   |
# |----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+----------+-----------+---------+--------------------|
# |  0 | Klebsiella pneumoniae strain F17KP0054 chromosome, complete genome                                                                                                                                    | CP052136.1   |  5357257 |         0 |    6156 | CP052136           |
# |  1 | Klebsiella pneumoniae isolate 97ca48c2-b809-11e8-aae5-3c4a9275d6c8 genome assembly, chromosome: 1 >gi|1772506384|emb|LR736022.1| Klebsiella pneumoniae strain Kp_17035 genome assembly, chromosome: 1 | LR596810.1   |  5577545 |         0 |    6156 | LR596810           |
# |  2 | Klebsiella pneumoniae strain JS187 chromosome, complete genome                                                                                                                                        | CP025466.1   |  5359967 |         0 |    6156 | CP025466           |
# |  3 | Klebsiella pneumoniae strain JS706 chromosome, complete genome                                                                                                                                        | CP070970.1   |  5339678 |         0 |    6156 | CP070970           |
# |  4 | Klebsiella pneumoniae subsp. pneumoniae HS11286, complete genome                                                                                                                                      | CP003200.1   |  5333942 |         0 |    6156 | CP003200           |
# |  5 | Klebsiella pneumoniae strain 1613015451 chromosome, complete genome                                                                                                                                   | CP083066.1   |  5340602 |         0 |    6111 | CP083066           |
# |  6 | Klebsiella pneumoniae strain KSB1_1B genome assembly, chromosome: 1                                                                                                                                   | LR890291.1   |  5252324 |         0 |    6111 | LR890291           |
# |  7 | Klebsiella pneumoniae strain FDAARGOS_1313 chromosome, complete genome                                                                                                                                | CP069907.1   |  5220139 |         0 |    6081 | CP069907           |
# |  8 | Klebsiella pneumoniae strain RHBSTW-00433 chromosome, complete genome                                                                                                                                 | CP056530.1   |  5240044 |         0 |    6081 | CP056530           |
